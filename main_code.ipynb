# %%
import importlib
from sqlalchemy import create_engine

import src.etl as etl
import src.dq_rules as dq_rules

# Force reload during development
importlib.reload(etl)
importlib.reload(dq_rules)


def get_engine():
    connection_string = (
        "mssql+pyodbc://LAPTOP-R4HOBLDM\\SQLEXPRESS/CMS_PDS_DATA"
        "?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
    )
    return create_engine(connection_string)


def main():
    engine = get_engine()
    csv_path = "data/raw/provider_specific_file.csv"
    etl.run_etl(csv_path, engine)


main()
# Out:
# ETL completed successfully

# %%
import src.dq_rules as dq_rules
dir(dq_rules)
# Out:
# ['DATE_FIELDS',
#  'NUMERIC_FIELDS',
#  'REQUIRED_FIELDS',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'datetime',
#  'dq_issue',
#  'is_missing',
#  'is_valid_date',
#  'json',
#  'pd',
#  'run_dq_checks']

# %%
from sqlalchemy import create_engine, text

engine = create_engine(
    "mssql+pyodbc://LAPTOP-R4HOBLDM\\SQLEXPRESS/CMS_PDS_DATA"
    "?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

try:
    with engine.connect() as conn:
        result = conn.execute(text("SELECT GETDATE()"))
        print("Connected successfully. SQL Server time:", result.fetchone()[0])
except Exception as e:
    print("Connection failed:", e)
# Out:
# Connected successfully. SQL Server time: 2025-12-30 23:13:31.103000

# %%
from sqlalchemy import create_engine
from etl import run_etl

connection_string = (
    "mssql+pyodbc://LAPTOP-R4HOBLDM\\SQLEXPRESS/CMS_PDS_DATA"
    "?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

engine = create_engine(connection_string)

run_etl("data/raw/provider_specific_file.csv", engine)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 11
#       4 connection_string = (
#       5     "mssql+pyodbc://LAPTOP-R4HOBLDM\\SQLEXPRESS/CMS_PDS_DATA"
#       6     "?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
#       7 )
#       9 engine = create_engine(connection_string)
# ---> 11 run_etl("data/raw/provider_specific_file.csv", engine)
#
# File c:\Users\Ibikh\Documents\GitHub\cms-insurance-pipeline\src\etl.py:262, in run_etl(csv_path, engine)
#     253 except Exception as e:
#     254     complete_etl_log(
#     255         engine,
#     256         run_id,
#    (...)
#     260         str(e)
#     261     )
# --> 262     raise e
#
# File c:\Users\Ibikh\Documents\GitHub\cms-insurance-pipeline\src\etl.py:219, in run_etl(csv_path, engine)
#     215 run_id = start_etl_log(engine, csv_path)
#     217 try:
#     218     # Load + clean
# ...
